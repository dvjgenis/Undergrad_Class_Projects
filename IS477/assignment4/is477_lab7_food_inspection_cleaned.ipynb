# %%
import pandas as pd

# %%
df = pd.read_csv("is477_lab7_food_inspection_cleaned.csv")
df
# Out:
#       Inspection ID                        DBA Name               AKA Name  \
# 0         2078801.0           THREE CHEFS RESTURANT  THREE CHEFS RESTURANT
# 1               NaN                             NaN                    NaN
# 2               NaN                             NaN                    NaN
# 3               NaN                             NaN                    NaN
# 4               NaN                             NaN                    NaN
# ...             ...                             ...                    ...
# 2135            NaN                             NaN                    NaN
# 2136            NaN                             NaN                    NaN
# 2137        58235.0  THE DINING ROOM AT KENDALL NFP        THE DINING ROOM
# 2138            NaN                             NaN                    NaN
# 2139        67793.0                    Carson (New)           Carson (New)
#
# ...

# %%
top_fail_zipcodes = df[df['Results'] == 'Fail']['Zip'].value_counts().head(3)

top_fail_zipcodes
# Out:
# Zip
# 60642.0    17
# 60618.0     9
# 60612.0     8
# Name: count, dtype: int64
