# %% [markdown]
# # STAT 207 Group Lab Assignment 9 - [10 total points]
#
# ## Linear Regression

# %% [markdown]
# <hr>

# %% [markdown]
# ## <u>Lab Grading</u>:
#
# Should we grade your submission?  If not, write the netID of the submission to be graded.  (Note: We will only grade one assignment per group, and we'll pick the first one that says we should grade that submission.  We will assign the same grade to all team members.)
#
# *For example*, you might respond: **grade this submission** or **my submission is under netID jdeeke**

# %% [markdown]
# grade this submission

# %% [markdown]
# If you said **my submission is under netID** above, we will not read any more of your lab submission.
#
# If you said **grade this submission** above, who worked with you on this submission?  Write both their **names** and **netIDs**.
#
# Also, discuss and record what your *dream car* would be.

# %% [markdown]
# **Worked independently due to medical emergency**
#
# Dream car would be a Hummer H2

# %% [markdown]
# <hr>

# %% [markdown]
# ## <u>Purpose</u>:
# You should work in groups of 2-3 on this report (not working in groups without permission will result in a point deduction). The purpose of this group lab assignment is to fit an interpret a multiple linear regression model.
# <hr>

# %% [markdown]
# ## <u>Assignment Instructions</u>:

# %% [markdown]
# ### Group Roles
#
# Suggested and specified roles are provided below:
#
# #### Groups of 2
#
# * **Driver**: This student will type the report.  While typing the report, you may be the one who is selecting the functions to apply to the data.
# * **Navigator**: This student will guide the process of answering the question.  Specific ways to help may include: outlining the general steps needed to solve a question (providing the overview), locating examples within the course notes, and reviewing each line of code as it is typed.
#
# #### Groups of 3
#
# * **Driver**: This student will type the report.  They may also be the one to select the functions to apply to the data.
# * **Navigator**: This student will guide the process of answering the question.  They may select the general approach to answering the question and/or a few steps to be completed along the way.
# * **Communicator**: This student will review the report (as it is typed) to ensure that it is clear and concise.  This student may also locate relevant examples within the course notes that may help complete the assignment.
#
# <hr>
#
# ### Imports

# %%
#Run this
import pandas as pd                    # imports pandas and calls the imported version 'pd'
import matplotlib.pyplot as plt        # imports the package and calls it 'plt'
import seaborn as sns                  # imports the seaborn package with the imported name 'sns'
sns.set()

# %% [markdown]
# ## Car Sales Data
#
# The car sales dataset contains the following variables for used cars listed for sale from cardekho.com (an online car sales platform based in India):
#
# - **name**: the type of car for sale
# - **year**: the year in which the car was bought
# - **selling_price**: the listed selling price of the car (in rupees; currently 1 rupee = 0.012 USD)
# - **km_driven**: the total mileage of the car, in kilometers
# - **fuel**: the type of fuel needed for the car
# - **seller_type**: reports if the car is sold by an individual or a dealer
# - **transmission**: gear transmission of the car (Automatic/Manual)
# - **owner**: number of previous owners of the car
# - **mileage_kmpl**: the fuel efficiency mileage, in kilometers per Liter
# - **engine_CC**: the engine capacity of the car, in cubic centimeters
# - **max_power_bhp**: the maximum power of the engine, in brake horse power
# - **seats**: the number of seats in the car.
#
# Use the car sales dataset in this folder (car_sales.csv) to perform the following analyses.
#
# ### 1. [1.5 point] Reading in and Cleaning the Data
#
# **a)** First, read in the data.  Note that missing values are recorded as blanks and should be called in Python as "".  Then drop the rows that have NAs in them.

# %%
df_initial = pd.read_csv('car_sales.csv', na_values=[""])
df_initial.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage_kmpl     221
# engine_CC        221
# max_power_bhp    216
# seats            221
# dtype: int64

# %%
df = df_initial.dropna()
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage_kmpl     0
# engine_CC        0
# max_power_bhp    0
# seats            0
# dtype: int64

# %%
print(df_initial.shape[0])
print(df.shape[0])
# Out:
# 8128
# 7906

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage_kmpl     float64
# engine_CC        float64
# max_power_bhp    float64
# seats            float64
# dtype: object

# %% [markdown]
# **b)** We'll aim to predict the selling price of a used car.  Pick two categorical and two quantitative variables to use as potential predictors.  Record these variables below.

# %% [markdown]
# ##### Categorical Variables:
# - **fuel**: the type of fuel needed for the car
# - **transmission**: gear transmission of the car (Automatic/Manual)
#
# ##### Quantitative Variables:
# - **km_driven**: the total mileage of the car, in kilometers
# - **engine_CC**: the engine capacity of the car, in cubic centimeters

# %% [markdown]
# ### 2. [4 points] Fitting a Model
#
# **a)** Now, fit a linear model predicting price from your four predictors of interest.

# %%
import statsmodels.formula.api as smf
results = smf.ols('selling_price ~ fuel + transmission + km_driven + engine_CC', data = df).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          selling_price   R-squared:                       0.488
# Model:                            OLS   Adj. R-squared:                  0.488
# Method:                 Least Squares   F-statistic:                     1256.
# Date:                Fri, 25 Oct 2024   Prob (F-statistic):               0.00
# Time:                        22:34:46   Log-Likelihood:            -1.1616e+05
# No. Observations:                7906   AIC:                         2.323e+05
# Df Residuals:                    7899   BIC:                         2.324e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# Intercept                1.09e+06   8.66e+04     12.589      0.000     9.2e+05    1.26e+06
# fuel[T.Diesel]          1.017e+05   8.18e+04      1.244      0.213   -5.85e+04    2.62e+05
# fuel[T.LPG]            -1747.5892   1.27e+05     -0.014      0.989   -2.51e+05    2.48e+05
# fuel[T.Petrol]         -9.697e+04   8.14e+04     -1.191      0.234   -2.57e+05    6.26e+04
# transmission[T.Manual] -1.107e+06   2.13e+04    -51.980      0.000   -1.15e+06   -1.07e+06
# km_driven                 -3.2512      0.124    -26.185      0.000      -3.495      -3.008
# engine_CC                502.8749     16.288     30.873      0.000     470.945     534.804
# ==============================================================================
# Omnibus:                     5745.023   Durbin-Watson:                   1.555
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           180579.998
# Skew:                           3.127   Prob(JB):                         0.00
# Kurtosis:                      25.563   Cond. No.                     2.35e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.35e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# **b)** What is the baseline level for your model?

# %%
# Printing all unique values for categorical variables
print(df['fuel'].unique())
print(df['transmission'].unique())
# Out:
# ['Diesel' 'Petrol' 'LPG' 'CNG']
# ['Manual' 'Automatic']

# %% [markdown]
# The baseline level for this model is a car that uses CNG fuel and has an Automatic transmission

# %% [markdown]
# **c)** Write the fitted model, using appropriate notation (or clearly express the appropriate notation with words), based on your model from **part a**.

# %% [markdown]
# predicted_selling_price = 1090000 + (101700 * fuel_Diesel) + (-1747.5892 * fuel_LPG) + (−96970 * fuel_Petrol) + (−1107000 * transmission_Manual) + (-3.2512 * km_driven) + (502.8749 * engine_CC)

# %% [markdown]
# ### 3. [4.5 points] Interpreting Your Model
#
# Now that we've fitted a model, let's focus on what that model tells us about our variables.
#
# **a)** For what levels of our categorical variables would we anticipate that we would have the highest selling price?  For each of our quantitative predictors, would we prefer larger or smaller values to increase the anticipated selling price?

# %% [markdown]
# For our categorical variables, we would anticipate the highest selling price from a **Diesel car with Automatic transmission**, seeing as how Diesel has the highest positive effect on selling price compared to the other fuel types, and since the coefficient for Manual transmission is highly negative.
#
# For our quantitative variables, **lower values of km_driven and higher values of engine_CC** would be preferred for maximizing the selling price, as that would mean lower km driven (lower mileage) and high engine capacity, which is typically correlates with a higher value in a car.

# %% [markdown]
# **b)** Pick a car in the dataset (be sure to specify the car).  Predict the price for this car.

# %%
picked_car = df.sample(1)
picked_car[['name', 'year', 'fuel', 'transmission', 'engine_CC', 'km_driven', 'selling_price']]
# Out:
#                                          name  year    fuel transmission  \
# 3987  Toyota Fortuner 2.5 4x2 MT TRD Sportivo  2015  Diesel       Manual
#
#       engine_CC  km_driven  selling_price
# 3987     2494.0     120000        2000000

# %%
name = picked_car['name'].values[0]
year = picked_car['year'].values[0]
fuel_Diesel = 1 if picked_car['fuel'].values[0] == 'Diesel' else 0
fuel_LPG = 1 if picked_car['fuel'].values[0] == 'LPG' else 0
fuel_Petrol = 1 if picked_car['fuel'].values[0] == 'Petrol' else 0
transmission_Manual = 1 if picked_car['transmission'].values[0] == 'Manual' else 0
km_driven = picked_car['km_driven'].values[0]
engine_CC = picked_car['engine_CC'].values[0]
selling_price = picked_car['selling_price'].values[0]

print(f'Name: {name}')
print(f'Year: {year}')
print(f'Diesel: {fuel_Diesel}')
print(f'LPG: {fuel_LPG}')
print(f'Petrol: {fuel_Petrol}')
print(f'Manual: {transmission_Manual}')
print(f'Mileage: {km_driven} km')
print(f'Engine CC: {engine_CC} m^3')
print(f'Actual Price: ${selling_price}')
# Out:
# Name: Toyota Fortuner 2.5 4x2 MT TRD Sportivo
# Year: 2015
# Diesel: 1
# LPG: 0
# Petrol: 0
# Manual: 1
# Mileage: 120000 km
# Engine CC: 2494.0 m^3
# Actual Price: $2000000

# %%
# predicted_selling_price = 1090000 + (101700 * fuel_Diesel) + (-1747.5892 * fuel_LPG) + (−96970 * fuel_Petrol) + (−1107000 * transmission_Manual) + (-3.2512 * km_driven) + (502.8749 * engine_CC)

predicted_selling_price = predicted_selling_price = 1090000 + (101700 * fuel_Diesel) + (-1747.5892 * fuel_LPG) + (-96970 * fuel_Petrol) + (-1107000 * transmission_Manual) + (-3.2512 * km_driven) + (502.8749 * engine_CC)
print(f'The predicted price for a {year} {name} is ${predicted_selling_price}')
# Out:
# The predicted price for a 2015 Toyota Fortuner 2.5 4x2 MT TRD Sportivo is $948726.0006000001

# %% [markdown]
# **c)** What is the error in the predicting selling price of the car from part **b**?

# %%
Residual_Error = selling_price - predicted_selling_price

print(f'The error in the predicting selling price of the {year} {name} from part b is ${Residual_Error}')
# Out:
# The error in the predicting selling price of the 2015 Toyota Fortuner 2.5 4x2 MT TRD Sportivo from part b is $1051273.9993999999

# %% [markdown]
# **d)** From part **b**, you calculated a predicted price.  Fill in the blanks: the predicted price is the _______ _______ price for cars with the characteristics of this car.
#
# *Hint:* you might look at the coefficient interpretations for hints about what it is exactly that we are predicting.  This also helps to address why you (likely) found that your prediction was not exactly correct in part **c**.

# %% [markdown]
# The predicted price is the **average expected** price for cars with the characteristics of this car.
